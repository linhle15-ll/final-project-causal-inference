# %% [markdown]
# (final_template)=
#
# # Final Project: Data Preprocessing
#
# :::{epigraph}
#
# -- Student name: Ngoc Linh Le
# :::

# %% [markdown]
# The purpose of data process is to prepare a clean and focused data frame for the final project: Estimating the Causal Effect of High Short Video Usage on Academic Performance Among Elementary Students.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import ipywidgets as widgets

# %%
# import dataset
vid_df = pd.read_excel('~/comsc341cd.github.io/projects/final_project/final-data.xlsx')
vid_df
# Out:
#       1.No.  2.gender  3.school  4.grade  5.class  6.The role of the "filler"  \
# 0         1         1         1        2        3                           2
# 1         2         1         1        2        3                           2
# 2         3         2         1        2        3                           2
# 3         4         2         1        5        2                           2
# 4         5         1         1        2        3                           2
# ...     ...       ...       ...      ...      ...                         ...
# 1047   1082         2         2        2        2                           2
# 1048   1083         2         2        2        2                           2
# 1049   1084         2         2        1        5                           2
# 1050   1085         1         2        3        4                           2
# 1051   1086         1         2        3        3                           2
#
#       7、What is your academic qualification?  \
# 0                                          6
# 1                                          5
# 2                                          5
# 3                                          5
# 4                                          5
# ...                                      ...
# 1047                                       4
# 1048                                       5
# 1049                                       6
# 1050                                       4
# 1051                                       2
#
#       8.Does he have his own cell phone?  9.Does he have his own tablet?  \
# 0                                      2                               1
# 1                                      2                               2
# 2                                      2                               2
# 3                                      2                               2
# 4                                      2                               1
# ...                                  ...                             ...
# 1047                                   2                               2
# 1048                                   2                               2
# 1049                                   2                               1
# 1050                                   2                               1
# 1051                                   1                               2
#
#       10.Parental Intervention (Time limit )  ...  Subjective SVU8  \
# 0                                        NaN  ...                1
# 1                                        NaN  ...                2
# 2                                        1.0  ...                1
# 3                                        1.0  ...                0
# 4                                        1.0  ...                3
# ...                                      ...  ...              ...
# 1047                                     NaN  ...                5
# 1048                                     NaN  ...                3
# 1049                                     NaN  ...                2
# 1050                                     NaN  ...                3
# 1051                                     1.0  ...                4
#
#       Attention1  Attention2  Attention3  Attention4  Att Total  \
# 0             73          16          18          56        163
# 1            114          11          13          79        217
# 2             69          33          16          66        184
# 3             74          25          27          96        222
# 4             53           5           8          40        106
# ...          ...         ...         ...         ...        ...
# 1047          67          15          20           1        103
# 1048          46           2           8          22         78
# 1049          61          25          22          64        172
# 1050          59          16          13          66        154
# 1051          65          14           6          39        124
#
#       Academic：chinese  Academic：math  Academic：English  Academic：Total
# 0                 99.0           78.0              99.0           276.0
# 1                100.0           95.0             100.0           295.0
# 2                100.0           89.0             100.0           289.0
# 3                 78.0           86.0              80.0           244.0
# 4                 95.0           94.0              90.0           279.0
# ...                ...            ...               ...             ...
# 1047              60.0           48.5              89.0           197.5
# 1048              66.0           54.0              83.0           203.0
# 1049              98.0          100.0              93.0           291.0
# 1050              86.0          115.0              99.0           300.0
# 1051              71.5           70.0              70.5           212.0
#
# [1052 rows x 72 columns]

# %% [markdown]
# In particular, there are the following variables in the dataset:

# %%
# Column names 
vid_df.columns
# Out:
# Index(['1.No.', '2.gender', '3.school', '4.grade', '5.class',
#        '6.The role of the "filler"', '7、What is your academic qualification?',
#        '8.Does he have his own cell phone?', '9.Does he have his own tablet?',
#        '10.Parental Intervention (Time limit )',
#        '10.Parental Intervention (Duration restrictions )',
#        '10.Parental Intervention (content)',
#        '10.Parental Intervention (No restrictions )',
#        '10.Parental Intervention ( I can't control it anymore.)',
#        '11.Is there any argument between parents and children on the use of electronic products?',
#        '12.does your child enjoy watching short videos?',
#        '13.Parental Intervention (Time limit )',
#        '13.Parental Intervention (Duration restrictions )',
#        '13.Parental Intervention (content)',
#        '13.Parental Intervention (No restrictions )',
#        '13.Parental Intervention ( I can't control it anymore.)',
#        '14、Did you set "Teen Mode" on his short video app?',
#        '15、How long do you spend on average to use short videos every day?',
#        '1、Do you like to use short videos? ',
#        '2、What platforms do you usually watch short videos on?--Tiktok ',
#        '2、What platforms do you usually watch short videos on?--Quickhand ',
#        '2.Haokan', '2.Huoshan', '2. Xigua ', '2.Bilibili ', '2.Wechat  vedio',
#        '2.Others--',
#        '3、What types of short videos do you often watch? --Funny categories',
#        '3.Leisure', '3.interests', '3.study classes', '3. game categories',
#        '3.current affairs', '3.variety', '3.Film and television editing',
#        '3.Campus life category', '3.Others',
#        '4.After watching a short video, do you do any of the following? -will  give a like ',
#        '4.will give a tip ', '4.will share ', '4.will comment ',
#        '4.will interact with friends in the comment ',
#        '4.will just watch and will not do any of the above',
#        'Do you shoot and upload your own short videos?', 'Objective SVU1',
#        'Objective SVU2', 'Objective SVU3', 'Objective SVU4', 'Objective SVU5',
#        'Objective SVU6', 'Subjective SVU1', 'Subjective SVU2',
#        'Subjective SVU3', 'Subjective SVU4', 'Subjective SVU5',
#        'Subjective SVU6', 'Subjective SVU7', 'Subjective SVU8', 'Attention1',
#        'Attention2', 'Attention3', 'Attention4', 'Att Total',
#        'Academic：chinese', 'Academic：math', 'Academic：English',
#        'Academic：Total'],
#       dtype='object')

# %% [markdown]
# Based on the study design, I selected the variables most relevant to estimating the causal effect of high short-video usage on academic performance. The following code (1) renames the raw survey columns into clear, analysis-ready variable names, and (2) filters the dataset to include only the key covariates and outcome measures used in the causal analysis: student demographics (gender, school type, grade), parent's education level, daily short-video usage duration, and total exam score.

# %%
# rename columns
vid_df = vid_df.rename(columns={
    '2.gender':'gender', # student's gender
    '3.school':'school', # student's school type 
    '4.grade':'grade', # student's grade
    '7、What is your academic qualification?': 'parent_edu', # parent's education level
    '15、How long do you spend on average to use short videos every day?':'ave_short_video_usage/day', # daily short-video usage duration
    'Academic：Total':'exam_score' # total exam score 
})

# filter the important columns to focus on
vid_df = vid_df.loc[:, ['gender', 'school', 'grade', 'parent_edu', 'ave_short_video_usage/day', 'exam_score']]

# %%
# check NaN (nice!)
vid_df.isna().sum()
# Out:
# gender                       0
# school                       0
# grade                        0
# parent_edu                   0
# ave_short_video_usage/day    0
# exam_score                   0
# dtype: int64

# %% [markdown]
# To facilitate data analysis, I will transform the binary variable into 0/1 instead of 1/2 as currently.

# %%
vid_df['gender'] = (vid_df['gender'] == 1).astype(int) # male = 1, others (female) = 0
vid_df['school'] = (vid_df['school'] == 1).astype(int) # urban = 1, others (suburban) = 0
vid_df.head(10)
# Out:
#    gender  school  grade  parent_edu  ave_short_video_usage/day  exam_score
# 0       1       1      2           6                          3       276.0
# 1       1       1      2           5                          1       295.0
# 2       0       1      2           5                          5       289.0
# 3       0       1      5           5                          4       244.0
# 4       1       1      2           5                          3       279.0
# 5       1       1      4           4                          3       288.0
# 6       1       1      4           5                          1       283.0
# 7       1       1      4           4                          3       275.0
# 8       1       1      4           4                          3       278.0
# 9       0       1      4           5                          2       282.5

# %%
# Save processed data to a file and import it
# index can change when resort/ filter row/ reset index -> set index=False to prevent inconsistencies
vid_df.to_csv("preprocessed_data.csv", index=False) 
vid_df
# Out:
#       gender  school  grade  parent_edu  ave_short_video_usage/day  exam_score
# 0          1       1      2           6                          3       276.0
# 1          1       1      2           5                          1       295.0
# 2          0       1      2           5                          5       289.0
# 3          0       1      5           5                          4       244.0
# 4          1       1      2           5                          3       279.0
# ...      ...     ...    ...         ...                        ...         ...
# 1047       0       0      2           4                          3       197.5
# 1048       0       0      2           5                          3       203.0
# 1049       0       0      1           6                          2       291.0
# 1050       1       0      3           4                          4       300.0
# 1051       1       0      3           2                          3       212.0
#
# [1052 rows x 6 columns]
